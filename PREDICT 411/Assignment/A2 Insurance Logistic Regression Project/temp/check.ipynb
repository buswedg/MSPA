# %%
# !pip install sas7bdat
from sas7bdat import SAS7BDAT
with SAS7BDAT('Buswell-prediction.sas7bdat') as f:
    for row in f:
        print(row)
# Out:
# ...
#   Running setup.py bdist_wheel for sas7bdat: started
#   Running setup.py bdist_wheel for sas7bdat: finished with status 'done'
#   Stored in directory: C:\Users\darry\AppData\Local\pip\Cache\wheels\7f\c6\8a\7de68b956cc44c5bc0d19bee60950e8ed513aaa6c1cf0bb417
# Successfully built sas7bdat
# ...
# [Buswell-prediction.sas7bdat] header length 131072 != 8192
# ['INDEX', 'P_TARGET_FLAG', 'P_TARGET_AMT']
# [3.0, 0.15751892879389362, 1753.460064998359]
# [9.0, 0.28089159259704444, 3231.37082048071]
# [10.0, 0.10979571524269997, 1013.7543750232968]
# [18.0, 0.13733683057799995, 1406.3258766123085]
# [21.0, 0.09204898241230894, 2833.9944609588715]
# [30.0, 0.3381613130881905, 1651.7699541499392]
# [31.0, 0.5294413978013408, 1384.1162784346764]
# [37.0, 0.37058472285863053, 1598.417576729074]
# [39.0, 0.01576273124208759, 845.3713957286143]
# [47.0, 0.10456502098513852, 1774.8809979464945]
# [60.0, 0.033018083292070025, 1178.5323724716802]
# [62.0, 0.562970213044348, 1705.7722077006786]
# ...
